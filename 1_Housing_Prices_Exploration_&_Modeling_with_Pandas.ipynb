# %% [markdown]
# <a href="https://colab.research.google.com/github/radhakrishnan-omotec/realestate-repo/blob/main/1_Housing_Prices_Exploration_%26_Modeling_with_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Housing Prices Exploration & Modeling with Pandas**
#
# ## Author : Dev Raj Parekh
#
# ### Date : 14-04-2025
#
# This is my first Pandas notebook

# %% [markdown]
# ## 1. Environment Setup

# %%
## 1. Environment Setup
import pandas as pd

# %%
# !git clone https://github.com/radhakrishnan-omotec/realestate-repo.git
# Out:
# Cloning into 'realestate-repo'...
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 11 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (11/11), 1.04 MiB | 6.58 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
df = pd.read_csv('/content/realestate-repo/housing_price_dataset.csv')

# %%
df.head()
# Out:
#    SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 0        2126         4          1        Rural       1969  215355.283618
# 1        2459         3          2        Rural       1980  195014.221626
# 2        1860         2          1       Suburb       1970  306891.012076
# 3        2294         2          1        Urban       1996  206786.787153
# 4        2130         5          2       Suburb       2001  272436.239065
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['SquareFeet'].plot(kind='hist', bins=20, title='SquareFeet')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Bedrooms'].plot(kind='hist', bins=20, title='Bedrooms')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
df.tail()
# Out:
#        SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 49995        1282         5          3        Rural       1975  100080.865895
# 49996        2854         2          2       Suburb       1988  374507.656727
# 49997        2979         5          3       Suburb       1962  384110.555590
# 49998        2596         5          2        Rural       1984  380512.685957
# 49999        1572         5          3        Rural       2011  221618.583218

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import LabelEncoder
